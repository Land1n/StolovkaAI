# %% [markdown]
# # Поготовка данных

# %% [markdown]
# ## Выборка данных

# %% [markdown]
# Разделить видео на 3 категории:
# * test
# * validation
# * train

# %% [markdown]
# Используем программу Ffmpeg для нарезки видео

# %%
# !ffmpeg -i video_dataset/train1.mp4 -vf fps=1/2 image_train/1_img%03d.png
# Out:
# ffmpeg version 6.1.1-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
# ...

# %%
# !ffmpeg -i video_dataset/train2.mp4 -vf fps=1/2 image_train/2_img%03d.png
# Out:
# ffmpeg version 6.1.1-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
# ...

# %%
# !ffmpeg -i video_dataset/train4.mp4 -vf fps=1/2 image_train/4_img%03d.png
# Out:
# ffmpeg version 6.1.1-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
# ...

# %%
# !ffmpeg -i video_dataset/val1.mp4 -vf fps=1/2 image_validation/1_img%03d.png
# Out:
# ffmpeg version 6.1.1-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
# ...

# %%
# !ffmpeg -i video_dataset/val2.mp4 -vf fps=1/2 image_validation/2_img%03d.png
# Out:
# ffmpeg version 6.1.1-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
# ...

# %% [markdown]
# После нарезки у нас 128 фотографий для обучения и 86 фотографий для валидации.

# %% [markdown]
# ## Классификация данных
#
# Для разметки мы использовали сервис CVAT. Всего у нас 5 классов:
# 1. buyer - Человек, который находится у раздачи ( красный )
# 2. visitor - человек, который находится в зале ( синий )
# 3. staff - персонал заведения ( зеленый )
# 4. teacher - учитель ( желтый )
# 5. student - студент ( фиолетовый )

# %% [markdown]
# ![image.png](attachment:adb2a17b-83fe-409b-8aaf-a5702a8eb4e8.png)

# %% [markdown]
# После сохраняем данные в формате YOLO 1.1

# %% [markdown]
# ![image.png](attachment:76204528-ff1c-4969-85a7-ec2284d6d4a0.png)

# %% [markdown]
# Для обучения модели нам понадобится представить данные в более привычном формате для YOLO.
# Для этого будем пользоваться готовым репозиторием: https://github.com/ankhafizov/CVAT2YOLO

# %% [markdown]
# После использования репозитория мы получам такой результат:

# %% [markdown]
# ![image.png](attachment:22b6a24f-2611-412a-a620-f6335f63326f.png)

# %% [markdown]
# data.yaml </br>
# ![image.png](attachment:4ccae4fc-4d4d-4ae0-8969-77bbaf2de901.png)

# %% [markdown]
# ## Обучение модели

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

result = model.train(data='dataset_yolov8\data.yaml',epochs=50,imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.1.37 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.13 torch-2.2.1+cpu CPU (Intel Core(TM) i5-8300H 2.30GHz)
# ...
